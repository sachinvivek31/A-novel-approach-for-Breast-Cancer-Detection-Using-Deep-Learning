# %% [markdown]
# Breast Cancer Detection

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Data/Breast Cancer Dataset.csv")

# %%
print(df.describe().T)
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
# Unnamed: 32                0.0           NaN           NaN          NaN
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
# Unnamed: 32                        NaN            NaN           NaN
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01
# Unnamed: 32                       NaN

# %%
print(df.isnull().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
#Rename Dataset to Label to make it easy to understand
df = df.rename(columns={'diagnosis':'Label'})
print(df.dtypes)
# Out:
# id                           int64
# Label                       object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# Unnamed: 32                float64
# dtype: object

# %%
#Understand the data
sns.countplot(x="Label", data=df) #M - malignant   B - benign
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
####### Replace categorical values with numbers########
print("Distribution of data: ", df['Label'].value_counts())

#Define the dependent variable that needs to be predicted (labels)
y = df["Label"].values
print("Labels before encoding are: ", np.unique(y))

# Encoding categorical data from text (B and M) to integers (0 and 1)
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
Y = labelencoder.fit_transform(y) # M=1 and B=0
print("Labels after encoding are: ", np.unique(Y))
# Out:
# Distribution of data:  B    357
# M    212
# Name: Label, dtype: int64
# Labels before encoding are:  ['B' 'M']
# Labels after encoding are:  [0 1]

# %%
#Define x and normalize / scale values

#Define the independent variables. Drop label and ID, and normalize other data
X = df.drop(labels = ["Label", "id"], axis=1)
print(X.describe().T) #Needs scaling
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# area_se                  569.0   40.337079   45.491006    6.802000
# smoothness_se            569.0    0.007041    0.003003    0.001713
# compactness_se           569.0    0.025478    0.017908    0.002252
# concavity_se             569.0    0.031894    0.030186    0.000000
# concave points_se        569.0    0.011796    0.006170    0.000000
# symmetry_se              569.0    0.020542    0.008266    0.007882
# fractal_dimension_se     569.0    0.003795    0.002646    0.000895
# radius_worst             569.0   16.269190    4.833242    7.930000
# texture_worst            569.0   25.677223    6.146258   12.020000
# perimeter_worst          569.0  107.261213   33.602542   50.410000
# area_worst               569.0  880.583128  569.356993  185.200000
# smoothness_worst         569.0    0.132369    0.022832    0.071170
# compactness_worst        569.0    0.254265    0.157336    0.027290
# concavity_worst          569.0    0.272188    0.208624    0.000000
# concave points_worst     569.0    0.114606    0.065732    0.000000
# symmetry_worst           569.0    0.290076    0.061867    0.156500
# fractal_dimension_worst  569.0    0.083946    0.018061    0.055040
# Unnamed: 32                0.0         NaN         NaN         NaN
#
#                                 25%         50%          75%         max
# radius_mean               11.700000   13.370000    15.780000    28.11000
# texture_mean              16.170000   18.840000    21.800000    39.28000
# perimeter_mean            75.170000   86.240000   104.100000   188.50000
# area_mean                420.300000  551.100000   782.700000  2501.00000
# smoothness_mean            0.086370    0.095870     0.105300     0.16340
# compactness_mean           0.064920    0.092630     0.130400     0.34540
# concavity_mean             0.029560    0.061540     0.130700     0.42680
# concave points_mean        0.020310    0.033500     0.074000     0.20120
# symmetry_mean              0.161900    0.179200     0.195700     0.30400
# fractal_dimension_mean     0.057700    0.061540     0.066120     0.09744
# radius_se                  0.232400    0.324200     0.478900     2.87300
# texture_se                 0.833900    1.108000     1.474000     4.88500
# perimeter_se               1.606000    2.287000     3.357000    21.98000
# area_se                   17.850000   24.530000    45.190000   542.20000
# smoothness_se              0.005169    0.006380     0.008146     0.03113
# compactness_se             0.013080    0.020450     0.032450     0.13540
# concavity_se               0.015090    0.025890     0.042050     0.39600
# concave points_se          0.007638    0.010930     0.014710     0.05279
# symmetry_se                0.015160    0.018730     0.023480     0.07895
# fractal_dimension_se       0.002248    0.003187     0.004558     0.02984
# radius_worst              13.010000   14.970000    18.790000    36.04000
# texture_worst             21.080000   25.410000    29.720000    49.54000
# perimeter_worst           84.110000   97.660000   125.400000   251.20000
# area_worst               515.300000  686.500000  1084.000000  4254.00000
# smoothness_worst           0.116600    0.131300     0.146000     0.22260
# compactness_worst          0.147200    0.211900     0.339100     1.05800
# concavity_worst            0.114500    0.226700     0.382900     1.25200
# concave points_worst       0.064930    0.099930     0.161400     0.29100
# symmetry_worst             0.250400    0.282200     0.317900     0.66380
# fractal_dimension_worst    0.071460    0.080040     0.092080     0.20750
# Unnamed: 32                     NaN         NaN          NaN         NaN

# %%
#Scale / normalize the values to bring them to similar range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)
print(X)  #Scaled values
# Out:
# [[0.52103744 0.0226581  0.54598853 ... 0.59846245 0.41886396        nan]
#  [0.64314449 0.27257355 0.61578329 ... 0.23358959 0.22287813        nan]
#  [0.60149557 0.3902604  0.59574321 ... 0.40370589 0.21343303        nan]
#  ...
#  [0.45525108 0.62123774 0.44578813 ... 0.12872068 0.1519087         nan]
#  [0.64456434 0.66351031 0.66553797 ... 0.49714173 0.45231536        nan]
#  [0.03686876 0.50152181 0.02853984 ... 0.25744136 0.10068215        nan]]
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %% [markdown]
# Spliting Dataset for Training and Testing

# %%
#Split data into train and test to verify accuracy after fitting the model.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)
print("Shape of training data is: ", X_train.shape)
print("Shape of testing data is: ", X_test.shape)
# Out:
# Shape of training data is:  (426, 31)
# Shape of testing data is:  (143, 31)

# %% [markdown]
# Importing the required library for Training the dataset

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
model = Sequential()
model.add(Dense(16, input_dim=30, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                496
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 513 (2.00 KB)
# Trainable params: 513 (2.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
import numpy as np

X_train = np.random.rand(1000,128,128,3)
y_train = np.random.rand(1000,2)
X_test = np.random.rand(200,128,128,3)
y_test = np.random.rand(200,2)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='sigmoid'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, verbose=1 , epochs=100, batch_size=64, validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 47s 3s/step - loss: 9.0660 - accuracy: 0.5160 - val_loss: 0.7502 - val_accuracy: 0.4050
# Epoch 2/100
# 16/16 [==============================] - 47s 3s/step - loss: 0.7648 - accuracy: 0.5150 - val_loss: 12.0568 - val_accuracy: 0.4050
# Epoch 3/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.7018 - accuracy: 0.5220 - val_loss: 37.7373 - val_accuracy: 0.4050
# Epoch 4/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6928 - accuracy: 0.5220 - val_loss: 17.7807 - val_accuracy: 0.5950
# Epoch 5/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6916 - accuracy: 0.5150 - val_loss: 25.0142 - val_accuracy: 0.5950
# Epoch 6/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6911 - accuracy: 0.5270 - val_loss: 32.4228 - val_accuracy: 0.5950
# Epoch 7/100
# 16/16 [==============================] - 47s 3s/step - loss: 0.6915 - accuracy: 0.5230 - val_loss: 38.9402 - val_accuracy: 0.5950
# Epoch 8/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.6913 - accuracy: 0.5230 - val_loss: 44.5118 - val_accuracy: 0.5950
# Epoch 9/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.6913 - accuracy: 0.5010 - val_loss: 49.9315 - val_accuracy: 0.5950
# Epoch 10/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6915 - accuracy: 0.5240 - val_loss: 54.9923 - val_accuracy: 0.5950
# Epoch 11/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6917 - accuracy: 0.5120 - val_loss: 61.1483 - val_accuracy: 0.5950
# Epoch 12/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6912 - accuracy: 0.5040 - val_loss: 67.5965 - val_accuracy: 0.5950
# Epoch 13/100
# 16/16 [==============================] - 46s 3s/step - loss: 0.6910 - accuracy: 0.5180 - val_loss: 72.0816 - val_accuracy: 0.5950
# Epoch 14/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.6907 - accuracy: 0.5360 - val_loss: 76.8647 - val_accuracy: 0.5950
# Epoch 15/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.6907 - accuracy: 0.5180 - val_loss: 84.1762 - val_accuracy: 0.5950
# Epoch 16/100
# 16/16 [==============================] - 46s 3s/step - loss: 0.6915 - accuracy: 0.5190 - val_loss: 92.7554 - val_accuracy: 0.5950
# Epoch 17/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6923 - accuracy: 0.5170 - val_loss: 104.3803 - val_accuracy: 0.5950
# Epoch 18/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6916 - accuracy: 0.5320 - val_loss: 107.8593 - val_accuracy: 0.5950
# Epoch 19/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6940 - accuracy: 0.4920 - val_loss: 111.4224 - val_accuracy: 0.5950
# Epoch 20/100
# 16/16 [==============================] - 48s 3s/step - loss: 0.6923 - accuracy: 0.5150 - val_loss: 127.0888 - val_accuracy: 0.5950
# Epoch 21/100
# 16/16 [==============================] - 48s 3s/step - loss: 0.6934 - accuracy: 0.5160 - val_loss: 132.4375 - val_accuracy: 0.5950
# Epoch 22/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.6947 - accuracy: 0.5350 - val_loss: 140.0202 - val_accuracy: 0.5950
# Epoch 23/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.7017 - accuracy: 0.5320 - val_loss: 146.3425 - val_accuracy: 0.5950
# Epoch 24/100
# 16/16 [==============================] - 47s 3s/step - loss: 0.7153 - accuracy: 0.5060 - val_loss: 160.2555 - val_accuracy: 0.5950
# Epoch 25/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.7258 - accuracy: 0.4750 - val_loss: 168.2519 - val_accuracy: 0.5950
# Epoch 26/100
# 16/16 [==============================] - 44s 3s/step - loss: 0.7007 - accuracy: 0.5180 - val_loss: 178.8683 - val_accuracy: 0.5950
# Epoch 27/100
# 16/16 [==============================] - 46s 3s/step - loss: 0.7170 - accuracy: 0.5250 - val_loss: 160.0153 - val_accuracy: 0.5950
# Epoch 28/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.7251 - accuracy: 0.4810 - val_loss: 143.2928 - val_accuracy: 0.5950
# Epoch 29/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.7690 - accuracy: 0.5190 - val_loss: 168.5063 - val_accuracy: 0.5950
# Epoch 30/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.7782 - accuracy: 0.4940 - val_loss: 255.7438 - val_accuracy: 0.5950
# Epoch 31/100
# 16/16 [==============================] - 43s 3s/step - loss: 0.9360 - accuracy: 0.5070 - val_loss: 333.6550 - val_accuracy: 0.5950
# Epoch 32/100
# 16/16 [==============================] - 43s 3s/step - loss: 1.0540 - accuracy: 0.5100 - val_loss: 209.1586 - val_accuracy: 0.5950
# Epoch 33/100
# 16/16 [==============================] - 45s 3s/step - loss: 1.0478 - accuracy: 0.4700 - val_loss: 11.7103 - val_accuracy: 0.4050
# Epoch 34/100
# 16/16 [==============================] - 43s 3s/step - loss: 1.1745 - accuracy: 0.4900 - val_loss: 88.1878 - val_accuracy: 0.4050
# Epoch 35/100
# 16/16 [==============================] - 42s 3s/step - loss: 1.3166 - accuracy: 0.5060 - val_loss: 132.8260 - val_accuracy: 0.4050
# Epoch 36/100
# 16/16 [==============================] - 43s 3s/step - loss: 2.0660 - accuracy: 0.5260 - val_loss: 433.5935 - val_accuracy: 0.4050
# Epoch 37/100
# 16/16 [==============================] - 45s 3s/step - loss: 2.5992 - accuracy: 0.5080 - val_loss: 420.2020 - val_accuracy: 0.4050
# Epoch 38/100
# 16/16 [==============================] - 42s 3s/step - loss: 2.5823 - accuracy: 0.5080 - val_loss: 443.9580 - val_accuracy: 0.4050
# Epoch 39/100
# 16/16 [==============================] - 43s 3s/step - loss: 4.9140 - accuracy: 0.4780 - val_loss: 763.3289 - val_accuracy: 0.4050
# Epoch 40/100
# 16/16 [==============================] - 43s 3s/step - loss: 3.6032 - accuracy: 0.4870 - val_loss: 559.4764 - val_accuracy: 0.4050
# Epoch 41/100
# 16/16 [==============================] - 45s 3s/step - loss: 9.0845 - accuracy: 0.4860 - val_loss: 1112.8298 - val_accuracy: 0.4050
# Epoch 42/100
# 16/16 [==============================] - 45s 3s/step - loss: 8.6918 - accuracy: 0.5050 - val_loss: 511.2520 - val_accuracy: 0.4050
# Epoch 43/100
# 16/16 [==============================] - 42s 3s/step - loss: 17.3202 - accuracy: 0.5200 - val_loss: 317.6072 - val_accuracy: 0.4050
# Epoch 44/100
# 16/16 [==============================] - 42s 3s/step - loss: 12.9783 - accuracy: 0.5080 - val_loss: 423.5892 - val_accuracy: 0.4050
# Epoch 45/100
# 16/16 [==============================] - 43s 3s/step - loss: 17.8056 - accuracy: 0.5010 - val_loss: 414.5150 - val_accuracy: 0.4050
# Epoch 46/100
# 16/16 [==============================] - 45s 3s/step - loss: 19.1891 - accuracy: 0.5160 - val_loss: 176.2431 - val_accuracy: 0.4050
# Epoch 47/100
# 16/16 [==============================] - 43s 3s/step - loss: 32.8063 - accuracy: 0.5100 - val_loss: 152.6647 - val_accuracy: 0.4050
# Epoch 48/100
# 16/16 [==============================] - 43s 3s/step - loss: 37.5250 - accuracy: 0.5080 - val_loss: 232.5679 - val_accuracy: 0.4050
# Epoch 49/100
# 16/16 [==============================] - 43s 3s/step - loss: 27.4181 - accuracy: 0.4730 - val_loss: 136.8448 - val_accuracy: 0.4050
# Epoch 50/100
# 16/16 [==============================] - 45s 3s/step - loss: 36.1035 - accuracy: 0.4940 - val_loss: 131.5002 - val_accuracy: 0.4050
# Epoch 51/100
# 16/16 [==============================] - 44s 3s/step - loss: 50.6530 - accuracy: 0.5100 - val_loss: 132.1342 - val_accuracy: 0.4050
# Epoch 52/100
# 16/16 [==============================] - 42s 3s/step - loss: 66.1043 - accuracy: 0.5110 - val_loss: 181.8813 - val_accuracy: 0.4050
# Epoch 53/100
# 16/16 [==============================] - 43s 3s/step - loss: 64.6861 - accuracy: 0.4880 - val_loss: 148.8549 - val_accuracy: 0.4050
# Epoch 54/100
# 16/16 [==============================] - 45s 3s/step - loss: 106.8828 - accuracy: 0.5140 - val_loss: 183.0889 - val_accuracy: 0.4050
# Epoch 55/100
# 16/16 [==============================] - 42s 3s/step - loss: 59.8209 - accuracy: 0.4920 - val_loss: 112.6081 - val_accuracy: 0.4050
# Epoch 56/100
# 16/16 [==============================] - 42s 3s/step - loss: 28.5931 - accuracy: 0.5310 - val_loss: 192.9920 - val_accuracy: 0.4050
# Epoch 57/100
# 16/16 [==============================] - 43s 3s/step - loss: 51.4225 - accuracy: 0.4970 - val_loss: 111.9586 - val_accuracy: 0.4050
# Epoch 58/100
# 16/16 [==============================] - 43s 3s/step - loss: 57.4479 - accuracy: 0.4790 - val_loss: 97.5886 - val_accuracy: 0.4050
# Epoch 59/100
# 16/16 [==============================] - 45s 3s/step - loss: 86.5930 - accuracy: 0.4940 - val_loss: 157.9296 - val_accuracy: 0.4050
# Epoch 60/100
# 16/16 [==============================] - 44s 3s/step - loss: 89.2187 - accuracy: 0.5250 - val_loss: 64.1472 - val_accuracy: 0.5150
# Epoch 61/100
# 16/16 [==============================] - 42s 3s/step - loss: 141.5312 - accuracy: 0.5150 - val_loss: 191.0597 - val_accuracy: 0.4050
# Epoch 62/100
# 16/16 [==============================] - 42s 3s/step - loss: 104.9803 - accuracy: 0.4750 - val_loss: 163.5943 - val_accuracy: 0.4050
# Epoch 63/100
# 16/16 [==============================] - 43s 3s/step - loss: 63.2714 - accuracy: 0.5130 - val_loss: 171.7660 - val_accuracy: 0.4050
# Epoch 64/100
# 16/16 [==============================] - 45s 3s/step - loss: 102.8134 - accuracy: 0.5090 - val_loss: 169.8105 - val_accuracy: 0.4050
# Epoch 65/100
# 16/16 [==============================] - 42s 3s/step - loss: 69.3746 - accuracy: 0.4770 - val_loss: 107.7350 - val_accuracy: 0.4050
# Epoch 66/100
# 16/16 [==============================] - 42s 3s/step - loss: 122.9758 - accuracy: 0.4750 - val_loss: 193.5795 - val_accuracy: 0.4050
# Epoch 67/100
# 16/16 [==============================] - 42s 3s/step - loss: 179.4208 - accuracy: 0.4920 - val_loss: 145.2564 - val_accuracy: 0.4050
# Epoch 68/100
# 16/16 [==============================] - 45s 3s/step - loss: 111.5145 - accuracy: 0.4950 - val_loss: 217.6784 - val_accuracy: 0.4050
# Epoch 69/100
# 16/16 [==============================] - 43s 3s/step - loss: 56.5150 - accuracy: 0.4960 - val_loss: 82.5894 - val_accuracy: 0.4050
# Epoch 70/100
# 16/16 [==============================] - 42s 3s/step - loss: 75.9307 - accuracy: 0.4990 - val_loss: 379.9901 - val_accuracy: 0.4050
# Epoch 71/100
# 16/16 [==============================] - 42s 3s/step - loss: 55.6019 - accuracy: 0.4940 - val_loss: 466.0076 - val_accuracy: 0.4050
# Epoch 72/100
# 16/16 [==============================] - 42s 3s/step - loss: 98.4456 - accuracy: 0.4880 - val_loss: 45.0147 - val_accuracy: 0.4050
# Epoch 73/100
# 16/16 [==============================] - 45s 3s/step - loss: 60.0277 - accuracy: 0.5060 - val_loss: 26.8385 - val_accuracy: 0.4050
# Epoch 74/100
# 16/16 [==============================] - 42s 3s/step - loss: 138.2270 - accuracy: 0.5170 - val_loss: 738.0329 - val_accuracy: 0.4050
# Epoch 75/100
# 16/16 [==============================] - 42s 3s/step - loss: 128.6798 - accuracy: 0.5100 - val_loss: 18.3270 - val_accuracy: 0.4300
# Epoch 76/100
# 16/16 [==============================] - 42s 3s/step - loss: 83.7592 - accuracy: 0.4830 - val_loss: 913.0237 - val_accuracy: 0.4050
# Epoch 77/100
# 16/16 [==============================] - 44s 3s/step - loss: 83.7469 - accuracy: 0.5080 - val_loss: 424.5350 - val_accuracy: 0.4050
# Epoch 78/100
# 16/16 [==============================] - 45s 3s/step - loss: 102.7550 - accuracy: 0.4690 - val_loss: 627.7952 - val_accuracy: 0.4050
# Epoch 79/100
# 16/16 [==============================] - 42s 3s/step - loss: 103.1006 - accuracy: 0.4830 - val_loss: 55.2814 - val_accuracy: 0.4100
# Epoch 80/100
# 16/16 [==============================] - 42s 3s/step - loss: 154.4644 - accuracy: 0.4770 - val_loss: 667.6534 - val_accuracy: 0.4050
# Epoch 81/100
# 16/16 [==============================] - 42s 3s/step - loss: 188.3486 - accuracy: 0.4770 - val_loss: 31.4135 - val_accuracy: 0.4650
# Epoch 82/100
# 16/16 [==============================] - 42s 3s/step - loss: 267.6053 - accuracy: 0.5090 - val_loss: 55.3592 - val_accuracy: 0.5950
# Epoch 83/100
# 16/16 [==============================] - 45s 3s/step - loss: 171.5636 - accuracy: 0.4630 - val_loss: 71.6355 - val_accuracy: 0.5950
# Epoch 84/100
# 16/16 [==============================] - 42s 3s/step - loss: 215.4104 - accuracy: 0.5070 - val_loss: 132.3669 - val_accuracy: 0.4050
# Epoch 85/100
# 16/16 [==============================] - 42s 3s/step - loss: 151.1934 - accuracy: 0.5040 - val_loss: 74.7686 - val_accuracy: 0.5950
# Epoch 86/100
# 16/16 [==============================] - 45s 3s/step - loss: 290.4651 - accuracy: 0.5220 - val_loss: 148.3576 - val_accuracy: 0.5950
# Epoch 87/100
# 16/16 [==============================] - 42s 3s/step - loss: 203.3891 - accuracy: 0.4930 - val_loss: 181.3839 - val_accuracy: 0.4050
# Epoch 88/100
# 16/16 [==============================] - 43s 3s/step - loss: 267.2136 - accuracy: 0.5130 - val_loss: 91.1419 - val_accuracy: 0.5950
# Epoch 89/100
# 16/16 [==============================] - 43s 3s/step - loss: 288.4585 - accuracy: 0.4860 - val_loss: 107.2169 - val_accuracy: 0.4050
# Epoch 90/100
# 16/16 [==============================] - 43s 3s/step - loss: 282.0000 - accuracy: 0.5170 - val_loss: 79.6853 - val_accuracy: 0.5950
# Epoch 91/100
# 16/16 [==============================] - 43s 3s/step - loss: 346.4099 - accuracy: 0.4940 - val_loss: 405.4576 - val_accuracy: 0.4050
# Epoch 92/100
# 16/16 [==============================] - 42s 3s/step - loss: 198.5992 - accuracy: 0.4650 - val_loss: 124.8606 - val_accuracy: 0.5950
# Epoch 93/100
# 16/16 [==============================] - 45s 3s/step - loss: 265.2319 - accuracy: 0.5130 - val_loss: 133.8255 - val_accuracy: 0.4050
# Epoch 94/100
# 16/16 [==============================] - 42s 3s/step - loss: 288.4221 - accuracy: 0.4920 - val_loss: 250.3820 - val_accuracy: 0.5950
# Epoch 95/100
# 16/16 [==============================] - 44s 3s/step - loss: 364.5276 - accuracy: 0.4710 - val_loss: 122.5249 - val_accuracy: 0.5950
# Epoch 96/100
# 16/16 [==============================] - 42s 3s/step - loss: 163.9494 - accuracy: 0.5090 - val_loss: 72.6191 - val_accuracy: 0.5950
# Epoch 97/100
# 16/16 [==============================] - 42s 3s/step - loss: 266.0193 - accuracy: 0.4850 - val_loss: 489.0233 - val_accuracy: 0.4050
# Epoch 98/100
# 16/16 [==============================] - 42s 3s/step - loss: 748.9261 - accuracy: 0.4800 - val_loss: 693.0875 - val_accuracy: 0.4050
# Epoch 99/100
# 16/16 [==============================] - 43s 3s/step - loss: 455.6670 - accuracy: 0.5410 - val_loss: 431.3658 - val_accuracy: 0.4050
# Epoch 100/100
# 16/16 [==============================] - 42s 3s/step - loss: 268.5103 - accuracy: 0.4800 - val_loss: 109.5284 - val_accuracy: 0.4050

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']  #Use accuracy if acc doesn't work
val_acc = history.history['val_accuracy']  #Use val_accuracy if acc doesn't work
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
